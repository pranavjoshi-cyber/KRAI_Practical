# %%
#Write a program for K means clustering model based on countries Longitude and
#Latitude data set 2

import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
data = pd.read_excel("C:/Users/Pranav/ML DL practical/Datasets/Countries_dataset2.xlsx")

# %%
data
# Out:
#             name   Longitude   Latitude
# 0     Mauritania  -10.347798  20.257367
# 1     Montserrat  -62.185185  16.739414
# 2      Mauritius   57.571206 -20.277687
# 3         Malawi   34.289356 -13.218081
# 4       Malaysia  109.697623   3.789868
# ..           ...         ...        ...
# 87         Samoa -172.164851 -13.753243
# 88         Yemen   47.586762  15.909280
# 89  South Africa   25.083901 -29.000341
# 90        Zambia   27.774759 -13.458242
# 91      Zimbabwe   29.851441 -19.004204
#
# [92 rows x 3 columns]

# %%
X = data[['Longitude', 'Latitude']]

# Define the number of clusters
n_clusters = 5  # You can adjust this based on your needs

# Create and fit the KMeans model
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(X)

# Get the cluster labels for each data point
labels = kmeans.labels_

# Add the cluster labels to the original dataset
data['Cluster'] = labels

# Get the cluster centers
cluster_centers = kmeans.cluster_centers_

# Visualize the clusters
plt.scatter(X['Longitude'], X['Latitude'], c=labels, cmap='rainbow')
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='black', marker='x')
plt.title("K-Means Clustering of Countries")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# Print the cluster centers (coordinates)
for i, center in enumerate(cluster_centers):
    print(f"Cluster {i + 1} Center: Longitude = {center[0]}, Latitude = {center[1]}")

# Optionally, you can save the labeled data to a new CSV file
data.to_csv("labeled_countries.csv", index=False)
# Out:
# C:\Users\Pranav\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Pranav\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Cluster 1 Center: Longitude = 36.379981735, Latitude = 40.79751004961539
# Cluster 2 Center: Longitude = -161.23583416666665, Latitude = -17.700963684999998
# Cluster 3 Center: Longitude = 137.29240401875, Latitude = -0.8274870506250025
# Cluster 4 Center: Longitude = -67.66025989894737, Latitude = 8.122308975789476
# Cluster 5 Center: Longitude = 20.5365061312, Latitude = -0.44750654240000287
